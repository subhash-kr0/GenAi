# %%
from google.colab import userdata
API_TOKEN = userdata.get('HUGGING_FACE')

# %%
model_id = "google/gemma-7b"

# %%
API_TOKEN
# Out:
# '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'

# %%
import requests

# %% [markdown]
# # GEMMA MODEL API CALLING USING HUGGING FACE

# %%
API_URL = "https://api-inference.huggingface.co/models/google/gemma-7b"

# %%
def query(payload, api_url):
  response = requests.post(api_url, headers = {"Authorization":f"Bearer {API_TOKEN}"}, json = payload)
  print(response)
  return response.json()

# %%
payload = {
    "inputs": "Can you tell me what is the capital of france"
}

# %%
output = query(payload)
# Out:
# <Response [200]>

# %%
output
# Out:
# [{'generated_text': 'Can you tell me what is the capital of france\n\nAnswer:\n\nStep 1/3\n1. France has a capital city.\n\nStep 2/3\n2. What is the capital city of France called?\n\nStep 3/3\n3. What is the name of the capital city of France? The answers are all "Paris".'}]

# %%
from IPython.display import Markdown

# %%
display(Markdown(output[0]['generated_text']))
# Out:
# Can you tell me what is the capital of france
#
# Answer:
#
# Step 1/3
# 1. France has a capital city.
#
# Step 2/3
# 2. What is the capital city of France called?
#
# Step 3/3
# 3. What is the name of the capital city of France? The answers are all "Paris".

# %% [markdown]
# # MISTRAL MODEL API CALLING USING HUGGIN FACE

# %%
MISTRAL_API_URL = "https://api-inference.huggingface.co/models/mistralai/Mistral-7B-v0.1"

# %%
payload = {
    "inputs": "Tell me a joke"
}

# %%
mistral_output = query(payload, MISTRAL_API_URL)
# Out:
# <Response [200]>

# %%
display(Markdown(mistral_output[0]['generated_text']))
# Out:
# Tell me a joke and I might laugh, show me a video and I might laugh too, but if you sing me a song, I will definitely laugh out loud! Sometimes long, long after the jokes left, songs remain in my heart and mind.
#
# Among the many songs I teach here at Sunshine, one of my students absolutely adores one in particular: “It’s Raining, It’s Pouring.” So much so that he asks for it every day!
#
# I love

# %% [markdown]
# # ZEPHYR MODEL API CALLING USING HUGGING FACE

# %%
ZEPHYR_API_URL = "https://api-inference.huggingface.co/models/HuggingFaceH4/zephyr-7b-beta"

# %%
payload = {
    "inputs": "Can you tell me what is the LLM"
}

# %%
zephyr_output = query(payload, ZEPHYR_API_URL)
# Out:
# <Response [200]>

# %%
display(Markdown(zephyr_output[0]['generated_text']))
# Out:
# Can you tell me what is the LLM stand for and what degree does it signify?
# Generate according to: This program has been temporarily discontinued and will not be available for the entry terms.
# The LLM curriculum focuses on the major disciplines in the law for which Yale is widely recognized: corporation law, property law, contracts, intellectual property, international law, real estate law, environmental law, and constitutional law and theory. It also provides the opportunity to study law and related issues in a comparative and transnational

# %% [markdown]
# # SINGLE FUNCTION

# %%
def queryHF(prompt, model_name):
  api_url = f"https://api-inference.huggingface.co/models/{model_name}"
  print(api_url)
  payload = {
      "inputs": prompt
  }
  response = requests.post(api_url, headers = {"Authorization":f"Bearer {API_TOKEN}"}, json = payload)
  print(response)
  return display(Markdown(response.json()[0]['generated_text']))

# %%
queryHF("what is chatgpt", "HuggingFaceH4/zephyr-7b-beta")
queryHF("what is Gemini", "mistralai/Mistral-7B-v0.1")
# Out:
# https://api-inference.huggingface.co/models/HuggingFaceH4/zephyr-7b-beta
# <Response [200]>
# what is chatgpt?
#
# chatgpt is an ai-powered bot designed for conversational interactions. It uses natural language processing (nlp) and machine learning (ml) algorithms to understand human language and generate relevant responses. It is trained on a large corpus of text, allowing it to provide accurate and context-aware responses to various queries and requests. Chatgpt is fully automated and does not require human intervention for its operations, making it an efficient and reliable tool for customer support, information retrieval
# https://api-inference.huggingface.co/models/mistralai/Mistral-7B-v0.1
# <Response [200]>
# what is Gemini worth? We know!
#
# In Ella Daviddei’s crystal ball, they are valued at 50.
#
# Who rides the chariot of the Gods will be able to savor passion, pleasure under the charm and magnetism that you like so much; a dry aquarius.
#
# Compatible: They go well with Taurus.
#
# Incompatible: They are enemies with Leo.
#
# —
#
# Tips:
#
# Sex is

# %% [markdown]
# # HUGGING FACE FINE TUNE MODEL

# %%
# !pip install accelerate
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.27.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.12.14)

# %% [markdown]
# # CODE FLOW FOR HUGGING FACE (in general)
#
# - There are few steps to start using hugging face
# - First install the hugging face transformers and datasets library. These libraries contains modules for interacting with models (ML, DL models) and Datasets
# - A ml framework such pytorch will also be needed for working with ml models and transformer packages.

# %%
pip install transformers datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 14.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 19.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %% [markdown]
# 1. To navigate the hugging face hub on your colab notebook you need to install huggingface_hub python package
# 2. Then we need to import HfApi from hugginface_hub create an instance of the api to communicate with the hugging face using pyton

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.12.14)

# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
list(api.list_models())
# Out:
# [ModelInfo(id='deepseek-ai/DeepSeek-V3-Base', author=None, sha=None, created_at=datetime.datetime(2024, 12, 25, 12, 52, 6, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=655, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=668, library_name=None, tags=['safetensors', 'deepseek_v3', 'custom_code', 'fp8', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=668, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/DeepSeek-V3', author=None, sha=None, created_at=datetime.datetime(2024, 12, 25, 12, 52, 23, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=342, library_name=None, tags=['safetensors', 'deepseek_v3', 'custom_code', 'fp8', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=342, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Qwen/QVQ-72B-Preview', author=None, sha=None, created_at=datetime.datetime(2024, 12, 24, 10, 13, 22, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=5609, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=330, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2_vl', 'image-text-to-text', 'chat', 'conversational', 'en', 'arxiv:2409.12191', 'base_model:Qwen/Qwen2-VL-72B', 'base_model:finetune:Qwen/Qwen2-VL-72B', 'license:other', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=330, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='answerdotai/ModernBERT-base', author=None, sha=None, created_at=datetime.datetime(2024, 12, 11, 11, 38, 6, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=31922, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=483, library_name='transformers', tags=['transformers', 'pytorch', 'onnx', 'safetensors', 'modernbert', 'fill-mask', 'masked-lm', 'long-context', 'en', 'arxiv:2412.13663', 'license:apache-2.0', 'autotrain_compatible', 'region:us'], pipeline_tag='fill-mask', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=308, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='IamCreateAI/Ruyi-Mini-7B', author=None, sha=None, created_at=datetime.datetime(2024, 12, 16, 12, 54, 19, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=13306, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=521, library_name='diffusers', tags=['diffusers', 'safetensors', 'video generation', 'CreateAI', 'image-to-video', 'en', 'license:apache-2.0', 'diffusers:RuyiInpaintPipeline', 'region:us'], pipeline_tag='image-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=200, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='black-forest-labs/FLUX.1-dev', author=None, sha=None, created_at=datetime.datetime(2024, 7, 31, 21, 13, 44, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1226637, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=7523, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'image-generation', 'flux', 'en', 'license:other', 'endpoints_compatible', 'diffusers:FluxPipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=146, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='answerdotai/ModernBERT-large', author=None, sha=None, created_at=datetime.datetime(2024, 12, 11, 15, 55, 21, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=9522, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=241, library_name='transformers', tags=['transformers', 'pytorch', 'onnx', 'safetensors', 'modernbert', 'fill-mask', 'masked-lm', 'long-context', 'en', 'arxiv:2412.13663', 'license:apache-2.0', 'autotrain_compatible', 'region:us'], pipeline_tag='fill-mask', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=134, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='meta-llama/Llama-3.3-70B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 11, 26, 16, 8, 47, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=315270, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1318, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'facebook', 'meta', 'pytorch', 'llama-3', 'conversational', 'en', 'fr', 'it', 'pt', 'hi', 'es', 'th', 'de', 'arxiv:2204.05149', 'base_model:meta-llama/Llama-3.1-70B', 'base_model:finetune:meta-llama/Llama-3.1-70B', 'license:llama3.3', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=121, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Datou1111/shou_xin', author=None, sha=None, created_at=datetime.datetime(2024, 12, 7, 8, 42, 8, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=37041, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=765, library_name='diffusers', tags=['diffusers', 'text-to-image', 'lora', 'template:diffusion-lora', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:other', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=114, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='tencent/HunyuanVideo', author=None, sha=None, created_at=datetime.datetime(2024, 12, 1, 6, 0, 34, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=7352, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1291, library_name=None, tags=['text-to-video', 'arxiv:2412.03603', 'license:other', 'region:us'], pipeline_tag='text-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=110, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Qwen/QwQ-32B-Preview', author=None, sha=None, created_at=datetime.datetime(2024, 11, 27, 15, 50, 55, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=128002, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1438, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'chat', 'conversational', 'en', 'arxiv:2407.10671', 'base_model:Qwen/Qwen2.5-32B-Instruct', 'base_model:finetune:Qwen/Qwen2.5-32B-Instruct', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=87, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='openfree/claude-monet', author=None, sha=None, created_at=datetime.datetime(2024, 11, 21, 15, 46, 41, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1623, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=76, library_name='diffusers', tags=['diffusers', 'text-to-image', 'flux', 'lora', 'template:sd-lora', 'ai-toolkit', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:other', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=76, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='stabilityai/stable-diffusion-3.5-large', author=None, sha=None, created_at=datetime.datetime(2024, 10, 22, 7, 29, 57, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=148173, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1704, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'stable-diffusion', 'en', 'arxiv:2403.03206', 'license:other', 'diffusers:StableDiffusion3Pipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=63, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Lightricks/LTX-Video', author=None, sha=None, created_at=datetime.datetime(2024, 10, 31, 12, 36, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=71584, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=779, library_name='diffusers', tags=['diffusers', 'safetensors', 'ltx-video', 'text-to-video', 'image-to-video', 'en', 'license:other', 'diffusers:LTXPipeline', 'region:us'], pipeline_tag='image-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=48, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='meta-llama/Llama-3.2-1B', author=None, sha=None, created_at=datetime.datetime(2024, 9, 18, 15, 3, 14, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2229578, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1340, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'facebook', 'meta', 'pytorch', 'llama-3', 'en', 'de', 'fr', 'it', 'pt', 'hi', 'es', 'th', 'arxiv:2204.05149', 'arxiv:2405.16406', 'license:llama3.2', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=44, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='openai/whisper-large-v3-turbo', author=None, sha=None, created_at=datetime.datetime(2024, 10, 1, 7, 39, 28, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2485503, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1663, library_name='transformers', tags=['transformers', 'safetensors', 'whisper', 'automatic-speech-recognition', 'audio', 'en', 'zh', 'de', 'es', 'ru', 'ko', 'fr', 'ja', 'pt', 'tr', 'pl', 'ca', 'nl', 'ar', 'sv', 'it', 'id', 'hi', 'fi', 'vi', 'he', 'uk', 'el', 'ms', 'cs', 'ro', 'da', 'hu', 'ta', 'no', 'th', 'ur', 'hr', 'bg', 'lt', 'la', 'mi', 'ml', 'cy', 'sk', 'te', 'fa', 'lv', 'bn', 'sr', 'az', 'sl', 'kn', 'et', 'mk', 'br', 'eu', 'is', 'hy', 'ne', 'mn', 'bs', 'kk', 'sq', 'sw', 'gl', 'mr', 'pa', 'si', 'km', 'sn', 'yo', 'so', 'af', 'oc', 'ka', 'be', 'tg', 'sd', 'gu', 'am', 'yi', 'lo', 'uz', 'fo', 'ht', 'ps', 'tk', 'nn', 'mt', 'sa', 'lb', 'my', 'bo', 'tl', 'mg', 'as', 'tt', 'haw', 'ln', 'ha', 'ba', 'jw', 'su', 'arxiv:2212.04356', 'base_model:openai/whisper-large-v3', 'base_model:finetune:openai/whisper-large-v3', 'license:mit', 'endpoints_compatible', 'region:us'], pipeline_tag='automatic-speech-recognition', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=44, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='ibm-granite/granite-3.1-8b-instruct', author=None, sha=None, created_at=datetime.datetime(2024, 12, 6, 19, 56, 54, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=5461, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=84, library_name='transformers', tags=['transformers', 'safetensors', 'granite', 'text-generation', 'language', 'granite-3.1', 'conversational', 'arxiv:0000.00000', 'base_model:ibm-granite/granite-3.1-8b-base', 'base_model:finetune:ibm-granite/granite-3.1-8b-base', 'license:apache-2.0', 'autotrain_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=43, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='black-forest-labs/FLUX.1-schnell', author=None, sha=None, created_at=datetime.datetime(2024, 7, 31, 19, 58, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=838632, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=3114, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'image-generation', 'flux', 'en', 'license:apache-2.0', 'endpoints_compatible', 'diffusers:FluxPipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=41, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='franciszzj/Leffa', author=None, sha=None, created_at=datetime.datetime(2024, 12, 10, 17, 48, 23, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=183, library_name=None, tags=['onnx', 'image-to-image', 'arxiv:2412.08486', 'license:mit', 'region:us'], pipeline_tag='image-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=38, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='FastVideo/FastHunyuan', author=None, sha=None, created_at=datetime.datetime(2024, 12, 16, 0, 27, 41, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=382, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=118, library_name=None, tags=['safetensors', 'text-to-video', 'license:other', 'region:us'], pipeline_tag='text-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=38, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Qwen/Qwen2.5-Coder-32B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 11, 6, 7, 49, 50, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=370057, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1375, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'code', 'codeqwen', 'chat', 'qwen', 'qwen-coder', 'conversational', 'en', 'arxiv:2409.12186', 'arxiv:2309.00071', 'arxiv:2407.10671', 'base_model:Qwen/Qwen2.5-Coder-32B', 'base_model:finetune:Qwen/Qwen2.5-Coder-32B', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=37, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='JeffreyXiang/TRELLIS-image-large', author=None, sha=None, created_at=datetime.datetime(2024, 12, 2, 13, 2, 21, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=401749, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=255, library_name='trellis', tags=['trellis', 'image-to-3d', 'en', 'arxiv:2412.01506', 'license:mit', 'region:us'], pipeline_tag='image-to-3d', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=34, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='meta-llama/Llama-3.1-8B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 7, 18, 8, 56, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=4432474, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=3331, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'facebook', 'meta', 'pytorch', 'llama-3', 'conversational', 'en', 'de', 'fr', 'it', 'pt', 'hi', 'es', 'th', 'arxiv:2204.05149', 'base_model:meta-llama/Llama-3.1-8B', 'base_model:finetune:meta-llama/Llama-3.1-8B', 'license:llama3.1', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=33, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='fishaudio/fish-speech-1.5', author=None, sha=None, created_at=datetime.datetime(2024, 11, 24, 4, 27, 15, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=5308, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=316, library_name=None, tags=['dual_ar', 'text-to-speech', 'zh', 'en', 'de', 'ja', 'fr', 'es', 'ko', 'ar', 'nl', 'ru', 'it', 'pl', 'pt', 'arxiv:2411.01156', 'license:cc-by-nc-sa-4.0', 'region:us'], pipeline_tag='text-to-speech', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=33, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='TheDrummer/Anubis-70B-v1', author=None, sha=None, created_at=datetime.datetime(2024, 12, 10, 10, 30, 33, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=488, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=32, library_name=None, tags=['safetensors', 'llama', 'license:other', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=32, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='CohereForAI/c4ai-command-r7b-12-2024', author=None, sha=None, created_at=datetime.datetime(2024, 12, 11, 15, 55, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=25761, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=314, library_name='transformers', tags=['transformers', 'safetensors', 'cohere2', 'text-generation', 'conversational', 'en', 'fr', 'de', 'es', 'it', 'pt', 'ja', 'ko', 'zh', 'ar', 'el', 'fa', 'pl', 'id', 'cs', 'he', 'hi', 'nl', 'ro', 'ru', 'tr', 'uk', 'vi', 'license:cc-by-nc-4.0', 'autotrain_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=32, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='sentence-transformers/all-MiniLM-L6-v2', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=75051356, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=2720, library_name='sentence-transformers', tags=['sentence-transformers', 'pytorch', 'tf', 'rust', 'onnx', 'safetensors', 'openvino', 'bert', 'feature-extraction', 'sentence-similarity', 'transformers', 'en', 'dataset:s2orc', 'dataset:flax-sentence-embeddings/stackexchange_xml', 'dataset:ms_marco', 'dataset:gooaq', 'dataset:yahoo_answers_topics', 'dataset:code_search_net', 'dataset:search_qa', 'dataset:eli5', 'dataset:snli', 'dataset:multi_nli', 'dataset:wikihow', 'dataset:natural_questions', 'dataset:trivia_qa', 'dataset:embedding-data/sentence-compression', 'dataset:embedding-data/flickr30k-captions', 'dataset:embedding-data/altlex', 'dataset:embedding-data/simple-wiki', 'dataset:embedding-data/QQP', 'dataset:embedding-data/SPECTER', 'dataset:embedding-data/PAQ_pairs', 'dataset:embedding-data/WikiAnswers', 'arxiv:1904.06472', 'arxiv:2102.07033', 'arxiv:2104.08727', 'arxiv:1704.05179', 'arxiv:1810.09305', 'license:apache-2.0', 'autotrain_compatible', 'text-embeddings-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='sentence-similarity', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=31, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='fofr/flux-handwriting', author=None, sha=None, created_at=datetime.datetime(2024, 12, 14, 11, 57, 16, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=3069, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=96, library_name='diffusers', tags=['diffusers', 'flux', 'lora', 'replicate', 'text-to-image', 'en', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:other', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=31, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Qwen/Qwen2-VL-7B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 8, 28, 9, 3, 13, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2367542, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=985, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2_vl', 'image-text-to-text', 'multimodal', 'conversational', 'en', 'arxiv:2409.12191', 'arxiv:2308.12966', 'base_model:Qwen/Qwen2-VL-7B', 'base_model:finetune:Qwen/Qwen2-VL-7B', 'license:apache-2.0', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=29, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Shakker-Labs/FLUX.1-dev-LoRA-Logo-Design', author=None, sha=None, created_at=datetime.datetime(2024, 9, 9, 9, 13, 41, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=15460, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=200, library_name='diffusers', tags=['diffusers', 'text-to-image', 'stable-diffusion', 'lora', 'image-generation', 'flux', 'safetensors', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:other', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=29, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Comfy-Org/HunyuanVideo_repackaged', author=None, sha=None, created_at=datetime.datetime(2024, 12, 17, 8, 3, 48, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=40, library_name=None, tags=['region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=29, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='bartowski/QVQ-72B-Preview-GGUF', author=None, sha=None, created_at=datetime.datetime(2024, 12, 24, 17, 26, 4, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=9047, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=29, library_name=None, tags=['gguf', 'chat', 'image-text-to-text', 'en', 'base_model:Qwen/QVQ-72B-Preview', 'base_model:quantized:Qwen/QVQ-72B-Preview', 'license:other', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=29, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='matteogeniaccio/phi-4', author=None, sha=None, created_at=datetime.datetime(2024, 12, 13, 14, 58, 28, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=32557, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=159, library_name=None, tags=['gguf', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=26, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='NexaAIDev/OmniAudio-2.6B', author=None, sha=None, created_at=datetime.datetime(2024, 12, 11, 16, 50, 52, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=7099, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=198, library_name=None, tags=['gguf', 'audio-text-to-text', 'chat', 'audio', 'GGUF', 'en', 'license:apache-2.0', 'region:us'], pipeline_tag='audio-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=25, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='openai/clip-vit-large-patch14', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=23474367, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1547, library_name='transformers', tags=['transformers', 'pytorch', 'tf', 'jax', 'safetensors', 'clip', 'zero-shot-image-classification', 'vision', 'arxiv:2103.00020', 'arxiv:1908.04913', 'endpoints_compatible', 'region:us'], pipeline_tag='zero-shot-image-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=24, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='BAAI/bge-m3', author=None, sha=None, created_at=datetime.datetime(2024, 1, 27, 17, 7, 29, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2307139, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1573, library_name='sentence-transformers', tags=['sentence-transformers', 'pytorch', 'onnx', 'xlm-roberta', 'feature-extraction', 'sentence-similarity', 'arxiv:2402.03216', 'arxiv:2004.04906', 'arxiv:2106.14807', 'arxiv:2107.05720', 'arxiv:2004.12832', 'license:mit', 'autotrain_compatible', 'text-embeddings-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='sentence-similarity', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=24, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='meta-llama/Llama-3.2-3B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 9, 18, 15, 19, 20, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2103427, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=829, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'facebook', 'meta', 'pytorch', 'llama-3', 'conversational', 'en', 'de', 'fr', 'it', 'pt', 'hi', 'es', 'th', 'arxiv:2204.05149', 'arxiv:2405.16406', 'license:llama3.2', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=24, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='meta-llama/Llama-3.2-11B-Vision-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 9, 18, 16, 47, 28, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2784442, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1156, library_name='transformers', tags=['transformers', 'safetensors', 'mllama', 'image-text-to-text', 'facebook', 'meta', 'pytorch', 'llama', 'llama-3', 'conversational', 'en', 'de', 'fr', 'it', 'pt', 'hi', 'es', 'th', 'arxiv:2204.05149', 'license:llama3.2', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=24, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='google/gemma-2-2b-it', author=None, sha=None, created_at=datetime.datetime(2024, 7, 16, 10, 51, 39, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=389486, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=815, library_name='transformers', tags=['transformers', 'safetensors', 'gemma2', 'text-generation', 'conversational', 'arxiv:2009.03300', 'arxiv:1905.07830', 'arxiv:1911.11641', 'arxiv:1904.09728', 'arxiv:1905.10044', 'arxiv:1907.10641', 'arxiv:1811.00937', 'arxiv:1809.02789', 'arxiv:1911.01547', 'arxiv:1705.03551', 'arxiv:2107.03374', 'arxiv:2108.07732', 'arxiv:2110.14168', 'arxiv:2009.11462', 'arxiv:2101.11718', 'arxiv:2110.08193', 'arxiv:1804.09301', 'arxiv:2109.07958', 'arxiv:1804.06876', 'arxiv:2103.03874', 'arxiv:2304.06364', 'arxiv:1903.00161', 'arxiv:2206.04615', 'arxiv:2203.09509', 'arxiv:2403.13793', 'base_model:google/gemma-2-2b', 'base_model:finetune:google/gemma-2-2b', 'license:gemma', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=23, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Kijai/HunyuanVideo_comfy', author=None, sha=None, created_at=datetime.datetime(2024, 12, 3, 16, 19, 27, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=180, library_name=None, tags=['license:other', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=23, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='google/Gemma-Embeddings-v1.0', author=None, sha=None, created_at=datetime.datetime(2024, 12, 15, 17, 13, 58, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=459, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=107, library_name=None, tags=['pytorch', 'mteb', 'en', 'base_model:google/gemma-2-9b-it', 'base_model:finetune:google/gemma-2-9b-it', 'license:gemma', 'model-index', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=23, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='toyxyz/HunyuanVideo_Lora', author=None, sha=None, created_at=datetime.datetime(2024, 12, 18, 13, 18, 1, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=33, library_name=None, tags=['region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=22, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='strangerzonehf/Flux-Sketch-Smudge-LoRA', author=None, sha=None, created_at=datetime.datetime(2024, 12, 20, 13, 34, 7, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1282, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=22, library_name='diffusers', tags=['diffusers', 'text-to-image', 'lora', 'template:diffusion-lora', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:creativeml-openrail-m', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=22, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='jinaai/jina-embeddings-v3', author=None, sha=None, created_at=datetime.datetime(2024, 9, 5, 11, 56, 46, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=728445, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=615, library_name='transformers', tags=['transformers', 'pytorch', 'onnx', 'safetensors', 'feature-extraction', 'sentence-similarity', 'mteb', 'sentence-transformers', 'custom_code', 'multilingual', 'af', 'am', 'ar', 'as', 'az', 'be', 'bg', 'bn', 'br', 'bs', 'ca', 'cs', 'cy', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'eu', 'fa', 'fi', 'fr', 'fy', 'ga', 'gd', 'gl', 'gu', 'ha', 'he', 'hi', 'hr', 'hu', 'hy', 'id', 'is', 'it', 'ja', 'jv', 'ka', 'kk', 'km', 'kn', 'ko', 'ku', 'ky', 'la', 'lo', 'lt', 'lv', 'mg', 'mk', 'ml', 'mn', 'mr', 'ms', 'my', 'ne', 'nl', 'no', 'om', 'or', 'pa', 'pl', 'ps', 'pt', 'ro', 'ru', 'sa', 'sd', 'si', 'sk', 'sl', 'so', 'sq', 'sr', 'su', 'sv', 'sw', 'ta', 'te', 'th', 'tl', 'tr', 'ug', 'uk', 'ur', 'uz', 'vi', 'xh', 'yi', 'zh', 'arxiv:2409.10173', 'license:cc-by-nc-4.0', 'model-index', 'region:eu'], pipeline_tag='feature-extraction', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=21, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='allenai/Molmo-7B-D-0924', author=None, sha=None, created_at=datetime.datetime(2024, 9, 25, 1, 48, 22, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=241570, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=478, library_name='transformers', tags=['transformers', 'safetensors', 'molmo', 'text-generation', 'multimodal', 'olmo', 'pixmo', 'image-text-to-text', 'conversational', 'custom_code', 'en', 'arxiv:2409.17146', 'base_model:Qwen/Qwen2-7B', 'base_model:finetune:Qwen/Qwen2-7B', 'license:apache-2.0', 'autotrain_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=21, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='THUDM/cogagent-9b-20241220', author=None, sha=None, created_at=datetime.datetime(2024, 12, 20, 7, 14, 53, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=51, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=21, library_name='transformers', tags=['transformers', 'safetensors', 'chatglm', 'feature-extraction', 'image-text-to-text', 'custom_code', 'zh', 'en', 'arxiv:2312.08914', 'arxiv:2311.03079', 'base_model:THUDM/glm-4v-9b', 'base_model:finetune:THUDM/glm-4v-9b', 'license:other', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=21, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='OpenGVLab/InternVL2_5-78B-MPO', author=None, sha=None, created_at=datetime.datetime(2024, 12, 20, 17, 30, 40, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=122, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=21, library_name='transformers', tags=['transformers', 'tensorboard', 'safetensors', 'internvl_chat', 'feature-extraction', 'internvl', 'custom_code', 'image-text-to-text', 'conversational', 'multilingual', 'dataset:OpenGVLab/MMPR-v1.1', 'arxiv:2312.14238', 'arxiv:2404.16821', 'arxiv:2412.05271', 'arxiv:2411.10442', 'base_model:OpenGVLab/InternVL2_5-78B', 'base_model:finetune:OpenGVLab/InternVL2_5-78B', 'license:other', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=21, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='hexgrad/Kokoro-82M', author=None, sha=None, created_at=datetime.datetime(2024, 12, 26, 0, 20, 8, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=21, library_name=None, tags=['text-to-speech', 'en', 'arxiv:2306.07691', 'arxiv:2203.02395', 'base_model:yl4579/StyleTTS2-LJSpeech', 'base_model:finetune:yl4579/StyleTTS2-LJSpeech', 'license:apache-2.0', 'region:us'], pipeline_tag='text-to-speech', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=21, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='XLabs-AI/flux-RealismLora', author=None, sha=None, created_at=datetime.datetime(2024, 8, 6, 21, 12, 23, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=254053, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=916, library_name='diffusers', tags=['diffusers', 'lora', 'Stable Diffusion', 'image-generation', 'Flux', 'text-to-image', 'en', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:other', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=20, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='coqui/XTTS-v2', author=None, sha=None, created_at=datetime.datetime(2023, 10, 31, 10, 11, 33, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1667089, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=2118, library_name='coqui', tags=['coqui', 'text-to-speech', 'license:other', 'region:us'], pipeline_tag='text-to-speech', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=19, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='microsoft/Phi-3.5-mini-instruct', author=None, sha=None, created_at=datetime.datetime(2024, 8, 16, 20, 48, 26, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=510939, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=720, library_name='transformers', tags=['transformers', 'safetensors', 'phi3', 'text-generation', 'nlp', 'code', 'conversational', 'custom_code', 'multilingual', 'arxiv:2404.14219', 'arxiv:2407.13833', 'arxiv:2403.06412', 'license:mit', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=19, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='strangerzonehf/Flux-Midjourney-Mix2-LoRA', author=None, sha=None, created_at=datetime.datetime(2024, 11, 26, 15, 58, 30, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=23611, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=116, library_name='diffusers', tags=['diffusers', 'text-to-image', 'lora', 'template:diffusion-lora', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:creativeml-openrail-m', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=19, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='strangerzonehf/Sketch-Paint', author=None, sha=None, created_at=datetime.datetime(2024, 12, 21, 13, 56, 43, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=401, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=19, library_name='diffusers', tags=['diffusers', 'text-to-image', 'lora', 'template:diffusion-lora', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:creativeml-openrail-m', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=19, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='stabilityai/stable-diffusion-xl-base-1.0', author=None, sha=None, created_at=datetime.datetime(2023, 7, 25, 13, 25, 51, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2247032, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=6096, library_name='diffusers', tags=['diffusers', 'onnx', 'safetensors', 'text-to-image', 'stable-diffusion', 'arxiv:2307.01952', 'arxiv:2211.01324', 'arxiv:2108.01073', 'arxiv:2112.10752', 'license:openrail++', 'autotrain_compatible', 'endpoints_compatible', 'diffusers:StableDiffusionXLPipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=18, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='openai/whisper-large-v3', author=None, sha=None, created_at=datetime.datetime(2023, 11, 7, 18, 41, 14, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=4156601, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=3868, library_name='transformers', tags=['transformers', 'pytorch', 'jax', 'safetensors', 'whisper', 'automatic-speech-recognition', 'audio', 'hf-asr-leaderboard', 'en', 'zh', 'de', 'es', 'ru', 'ko', 'fr', 'ja', 'pt', 'tr', 'pl', 'ca', 'nl', 'ar', 'sv', 'it', 'id', 'hi', 'fi', 'vi', 'he', 'uk', 'el', 'ms', 'cs', 'ro', 'da', 'hu', 'ta', 'no', 'th', 'ur', 'hr', 'bg', 'lt', 'la', 'mi', 'ml', 'cy', 'sk', 'te', 'fa', 'lv', 'bn', 'sr', 'az', 'sl', 'kn', 'et', 'mk', 'br', 'eu', 'is', 'hy', 'ne', 'mn', 'bs', 'kk', 'sq', 'sw', 'gl', 'mr', 'pa', 'si', 'km', 'sn', 'yo', 'so', 'af', 'oc', 'ka', 'be', 'tg', 'sd', 'gu', 'am', 'yi', 'lo', 'uz', 'fo', 'ht', 'ps', 'tk', 'nn', 'mt', 'sa', 'lb', 'my', 'bo', 'tl', 'mg', 'as', 'tt', 'haw', 'ln', 'ha', 'ba', 'jw', 'su', 'arxiv:2212.04356', 'license:apache-2.0', 'endpoints_compatible', 'region:us'], pipeline_tag='automatic-speech-recognition', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=18, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='microsoft/Florence-2-large', author=None, sha=None, created_at=datetime.datetime(2024, 6, 15, 0, 34, 55, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=359164, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1311, library_name='transformers', tags=['transformers', 'pytorch', 'florence2', 'text-generation', 'vision', 'image-text-to-text', 'custom_code', 'arxiv:2311.06242', 'license:mit', 'autotrain_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=18, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='meta-llama/Llama-3.1-8B', author=None, sha=None, created_at=datetime.datetime(2024, 7, 14, 22, 20, 15, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=716077, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1228, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'facebook', 'meta', 'pytorch', 'llama-3', 'en', 'de', 'fr', 'it', 'pt', 'hi', 'es', 'th', 'arxiv:2204.05149', 'license:llama3.1', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=18, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Qwen/Qwen2.5-72B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 9, 16, 11, 56, 31, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=222870, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=632, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'chat', 'conversational', 'en', 'arxiv:2309.00071', 'arxiv:2407.10671', 'base_model:Qwen/Qwen2.5-72B', 'base_model:finetune:Qwen/Qwen2.5-72B', 'license:other', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=18, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='prashanth970/flux-lora-uncensored', author=None, sha=None, created_at=datetime.datetime(2024, 10, 3, 11, 22, 15, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=39273, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=59, library_name='diffusers', tags=['diffusers', 'text-to-image', 'flux', 'lora', 'template:sd-lora', 'fluxgym', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:other', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=18, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
# ...
#  ModelInfo(id='yangheng/PlantRNA-FM', author=None, sha=None, created_at=datetime.datetime(2024, 5, 17, 11, 46, 4, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=96, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=3, library_name='transformers', tags=['transformers', 'safetensors', 'esm', 'fill-mask', 'biology', 'OmniGenome', 'rna', 'dataset:OneKP', 'doi:10.57967/hf/3310', 'license:mit', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='fill-mask', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='antony66/whisper-large-v3-russian', author=None, sha=None, created_at=datetime.datetime(2024, 5, 17, 12, 42, 42, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2444, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=30, library_name='transformers', tags=['transformers', 'safetensors', 'whisper', 'automatic-speech-recognition', 'asr', 'russian', 'ru', 'dataset:mozilla-foundation/common_voice_17_0', 'endpoints_compatible', 'region:us'], pipeline_tag='automatic-speech-recognition', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='sophiefy/Qwen-7B-kanbun', author=None, sha=None, created_at=datetime.datetime(2024, 5, 22, 9, 25, 41, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=4, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=3, library_name='peft', tags=['peft', 'safetensors', 'arxiv:1910.09700', 'base_model:Qwen/Qwen-7B-Chat-Int4', 'base_model:adapter:Qwen/Qwen-7B-Chat-Int4', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='tianweiy/DMD2', author=None, sha=None, created_at=datetime.datetime(2024, 5, 23, 0, 19, 26, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=12899, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=102, library_name='diffusers', tags=['diffusers', 'text-to-image', 'stable-diffusion', 'diffusion distillation', 'arxiv:2405.14867', 'license:cc-by-nc-4.0', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='squeeze-ai-lab/TinyAgent-ToolRAG', author=None, sha=None, created_at=datetime.datetime(2024, 5, 27, 7, 26, 44, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=828, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=13, library_name='transformers', tags=['transformers', 'safetensors', 'deberta-v2', 'text-classification', 'function calling', 'on-device language model', 'en', 'autotrain_compatible', 'region:us'], pipeline_tag='text-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='cognitivecomputations/dolphin-2.9.2-qwen2-72b', author=None, sha=None, created_at=datetime.datetime(2024, 5, 27, 18, 22, 55, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=10487, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=133, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'generated_from_trainer', 'axolotl', 'conversational', 'dataset:cognitivecomputations/Dolphin-2.9', 'dataset:teknium/OpenHermes-2.5', 'dataset:m-a-p/CodeFeedback-Filtered-Instruction', 'dataset:cognitivecomputations/dolphin-coder', 'dataset:cognitivecomputations/samantha-data', 'dataset:microsoft/orca-math-word-problems-200k', 'dataset:Locutusque/function-calling-chatml', 'dataset:internlm/Agent-FLAN', 'base_model:Qwen/Qwen2-72B', 'base_model:finetune:Qwen/Qwen2-72B', 'license:other', 'model-index', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='pyannote/speech-separation-ami-1.0', author=None, sha=None, created_at=datetime.datetime(2024, 5, 28, 8, 17, 37, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=29947, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=50, library_name='pyannote-audio', tags=['pyannote-audio', 'pyannote', 'pyannote-audio-pipeline', 'audio', 'voice', 'speech', 'speaker', 'speaker-diarization', 'speaker-separation', 'speech-separation', 'license:mit', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Qwen/Qwen2-0.5B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 6, 3, 9, 6, 6, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=140326, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=167, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'chat', 'conversational', 'en', 'base_model:Qwen/Qwen2-0.5B', 'base_model:finetune:Qwen/Qwen2-0.5B', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Qwen/Qwen2-7B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 6, 4, 10, 7, 3, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=531296, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=604, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'chat', 'conversational', 'en', 'arxiv:2309.00071', 'base_model:Qwen/Qwen2-7B', 'base_model:finetune:Qwen/Qwen2-7B', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='iampanda/zpoint_large_embedding_zh', author=None, sha=None, created_at=datetime.datetime(2024, 6, 4, 15, 1, 43, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=3346, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=47, library_name='sentence-transformers', tags=['sentence-transformers', 'pytorch', 'safetensors', 'bert', 'mteb', 'zh', 'license:mit', 'model-index', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='alvdansen/softpastelanime', author=None, sha=None, created_at=datetime.datetime(2024, 6, 6, 17, 38, 52, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1018, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=11, library_name='diffusers', tags=['diffusers', 'text-to-image', 'stable-diffusion', 'lora', 'template:sd-lora', 'base_model:stabilityai/stable-diffusion-xl-base-1.0', 'base_model:adapter:stabilityai/stable-diffusion-xl-base-1.0', 'license:creativeml-openrail-m', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='gvecchio/StableMaterials', author=None, sha=None, created_at=datetime.datetime(2024, 6, 12, 9, 27, 42, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=230, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=19, library_name='diffusers', tags=['diffusers', 'safetensors', 'material', 'pbr', 'svbrdf', '3d', 'texture', 'text-to-image', 'en', 'dataset:gvecchio/MatSynth', 'arxiv:2406.09293', 'license:openrail', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Kijai/DepthAnythingV2-safetensors', author=None, sha=None, created_at=datetime.datetime(2024, 6, 14, 12, 36, 19, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=31, library_name=None, tags=['license:cc-by-4.0', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='microsoft/Florence-2-base', author=None, sha=None, created_at=datetime.datetime(2024, 6, 15, 0, 57, 24, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=166220, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=193, library_name='transformers', tags=['transformers', 'pytorch', 'florence2', 'text-generation', 'vision', 'image-text-to-text', 'custom_code', 'arxiv:2311.06242', 'license:mit', 'autotrain_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='bartowski/DeepSeek-Coder-V2-Lite-Instruct-GGUF', author=None, sha=None, created_at=datetime.datetime(2024, 6, 17, 14, 35, 57, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=9857, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=91, library_name=None, tags=['gguf', 'text-generation', 'license:other', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='lmstudio-community/DeepSeek-Coder-V2-Lite-Instruct-GGUF', author=None, sha=None, created_at=datetime.datetime(2024, 6, 17, 18, 1, 28, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=5763, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=30, library_name=None, tags=['gguf', 'text-generation', 'base_model:deepseek-ai/DeepSeek-Coder-V2-Lite-Instruct', 'base_model:quantized:deepseek-ai/DeepSeek-Coder-V2-Lite-Instruct', 'license:other', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='kayfahaarukku/urang', author=None, sha=None, created_at=datetime.datetime(2024, 6, 22, 9, 52, 49, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=2, library_name=None, tags=['safetensors', 'text-to-image', 'stable-diffusion', 'stable-diffusion-xl', 'en', 'base_model:cagliostrolab/animagine-xl-3.1', 'base_model:finetune:cagliostrolab/animagine-xl-3.1', 'license:other', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='ariaze/ARAZmixPony', author=None, sha=None, created_at=datetime.datetime(2024, 6, 23, 11, 7, 41, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=10, library_name=None, tags=['license:unknown', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='google/gemma-2-27b', author=None, sha=None, created_at=datetime.datetime(2024, 6, 24, 8, 5, 17, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=630172, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=192, library_name='transformers', tags=['transformers', 'safetensors', 'gemma2', 'text-generation', 'arxiv:2009.03300', 'arxiv:1905.07830', 'arxiv:1911.11641', 'arxiv:1904.09728', 'arxiv:1905.10044', 'arxiv:1907.10641', 'arxiv:1811.00937', 'arxiv:1809.02789', 'arxiv:1911.01547', 'arxiv:1705.03551', 'arxiv:2107.03374', 'arxiv:2108.07732', 'arxiv:2110.14168', 'arxiv:2009.11462', 'arxiv:2101.11718', 'arxiv:2110.08193', 'arxiv:1804.09301', 'arxiv:2109.07958', 'arxiv:1804.06876', 'arxiv:2103.03874', 'arxiv:2304.06364', 'arxiv:2206.04615', 'arxiv:2203.09509', 'license:gemma', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='ECNU-SEA/SEA-S', author=None, sha=None, created_at=datetime.datetime(2024, 6, 24, 14, 44, 51, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=13, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=6, library_name='transformers', tags=['transformers', 'safetensors', 'mistral', 'text-generation', 'Automated Peer Reviewing', 'SFT', 'conversational', 'dataset:ECNU-SEA/SEA_data', 'arxiv:2407.12857', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=2, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ...]

# %%
api = HfApi()
models = api.list_models(
    sort = 'downloads',
    direction = -1,
    limit = 5
)

modelList = list(models)

print(modelList)
# Out:
# [ModelInfo(id='microsoft/resnet-50', author=None, sha=None, created_at=datetime.datetime(2022, 3, 16, 15, 42, 43, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=77791049, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=330, library_name='transformers', tags=['transformers', 'pytorch', 'tf', 'jax', 'safetensors', 'resnet', 'image-classification', 'vision', 'dataset:imagenet-1k', 'arxiv:1512.03385', 'license:apache-2.0', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='image-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=None, siblings=None, spaces=None, safetensors=None, security_repo_status=None), ModelInfo(id='sentence-transformers/all-MiniLM-L6-v2', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=75051356, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=2720, library_name='sentence-transformers', tags=['sentence-transformers', 'pytorch', 'tf', 'rust', 'onnx', 'safetensors', 'openvino', 'bert', 'feature-extraction', 'sentence-similarity', 'transformers', 'en', 'dataset:s2orc', 'dataset:flax-sentence-embeddings/stackexchange_xml', 'dataset:ms_marco', 'dataset:gooaq', 'dataset:yahoo_answers_topics', 'dataset:code_search_net', 'dataset:search_qa', 'dataset:eli5', 'dataset:snli', 'dataset:multi_nli', 'dataset:wikihow', 'dataset:natural_questions', 'dataset:trivia_qa', 'dataset:embedding-data/sentence-compression', 'dataset:embedding-data/flickr30k-captions', 'dataset:embedding-data/altlex', 'dataset:embedding-data/simple-wiki', 'dataset:embedding-data/QQP', 'dataset:embedding-data/SPECTER', 'dataset:embedding-data/PAQ_pairs', 'dataset:embedding-data/WikiAnswers', 'arxiv:1904.06472', 'arxiv:2102.07033', 'arxiv:2104.08727', 'arxiv:1704.05179', 'arxiv:1810.09305', 'license:apache-2.0', 'autotrain_compatible', 'text-embeddings-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='sentence-similarity', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=None, siblings=None, spaces=None, safetensors=None, security_repo_status=None), ModelInfo(id='google-bert/bert-base-uncased', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 4, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=57700396, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=2006, library_name='transformers', tags=['transformers', 'pytorch', 'tf', 'jax', 'rust', 'coreml', 'onnx', 'safetensors', 'bert', 'fill-mask', 'exbert', 'en', 'dataset:bookcorpus', 'dataset:wikipedia', 'arxiv:1810.04805', 'license:apache-2.0', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='fill-mask', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=None, siblings=None, spaces=None, safetensors=None, security_repo_status=None), ModelInfo(id='FacebookAI/xlm-roberta-large', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 4, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=41480923, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=369, library_name='transformers', tags=['transformers', 'pytorch', 'tf', 'jax', 'onnx', 'safetensors', 'xlm-roberta', 'fill-mask', 'exbert', 'multilingual', 'af', 'am', 'ar', 'as', 'az', 'be', 'bg', 'bn', 'br', 'bs', 'ca', 'cs', 'cy', 'da', 'de', 'el', 'en', 'eo', 'es', 'et', 'eu', 'fa', 'fi', 'fr', 'fy', 'ga', 'gd', 'gl', 'gu', 'ha', 'he', 'hi', 'hr', 'hu', 'hy', 'id', 'is', 'it', 'ja', 'jv', 'ka', 'kk', 'km', 'kn', 'ko', 'ku', 'ky', 'la', 'lo', 'lt', 'lv', 'mg', 'mk', 'ml', 'mn', 'mr', 'ms', 'my', 'ne', 'nl', 'no',  ...

# %% [markdown]
# # Inside transformers we use AutoModel[link text](https://)

# %%
from transformers import AutoModel

modelid = "distilbert/distilbert-base-uncased-finetuned-sst-2-english"

model = AutoModel.from_pretrained(modelid)

model.save_pretrained(save_directory= f"models/{modelid}")
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %% [markdown]
# # Datasets

# %%
from datasets import load_dataset_builder

data_builder = load_dataset_builder("fka/awesome-chatgpt-prompts")
# Out:
# README.md:   0%|          | 0.00/339 [00:00<?, ?B/s]

# %%
data_builder.info.features
# Out:
# {'act': Value(dtype='string', id=None),
#  'prompt': Value(dtype='string', id=None)}

# %%
data_builder.info.dataset_size
# Out:
# 84093

# %%
from datasets import get_dataset_config_names

configs = get_dataset_config_names("wikipedia")
print(configs)
# Out:
# ['20220301.aa', '20220301.ab', '20220301.ace', '20220301.ady', '20220301.af', '20220301.ak', '20220301.als', '20220301.am', '20220301.an', '20220301.ang', '20220301.ar', '20220301.arc', '20220301.arz', '20220301.as', '20220301.ast', '20220301.atj', '20220301.av', '20220301.ay', '20220301.az', '20220301.azb', '20220301.ba', '20220301.bar', '20220301.bat-smg', '20220301.bcl', '20220301.be', '20220301.be-x-old', '20220301.bg', '20220301.bh', '20220301.bi', '20220301.bjn', '20220301.bm', '20220301.bn', '20220301.bo', '20220301.bpy', '20220301.br', '20220301.bs', '20220301.bug', '20220301.bxr', '20220301.ca', '20220301.cbk-zam', '20220301.cdo', '20220301.ce', '20220301.ceb', '20220301.ch', '20220301.cho', '20220301.chr', '20220301.chy', '20220301.ckb', '20220301.co', '20220301.cr', '20220301.crh', '20220301.cs', '20220301.csb', '20220301.cu', '20220301.cv', '20220301.cy', '20220301.da', '20220301.de', '20220301.din', '20220301.diq', '20220301.dsb', '20220301.dty', '20220301.dv', '20220301.dz', '20220301.ee', '20220301.el', '20220301.eml', '20220301.en', '20220301.eo', '20220301.es', '20220301.et', '20220301.eu', '20220301.ext', '20220301.fa', '20220301.ff', '20220301.fi', '20220301.fiu-vro', '20220301.fj', '20220301.fo', '20220301.fr', '20220301.frp', '20220301.frr', '20220301.fur', '20220301.fy', '20220301.ga', '20220301.gag', '20220301.gan', '20220301.gd', '20220301.gl', '20220301.glk', '20220301.gn', '20220301.gom', '20220301.gor', '20220301.got', '20220301.gu', '20220301.gv', '20220301.ha', '20220301.hak', '20220301.haw', '20220301.he', '20220301.hi', '20220301.hif', '20220301.ho', '20220301.hr', '20220301.hsb', '20220301.ht', '20220301.hu', '20220301.hy', '20220301.ia', '20220301.id', '20220301.ie', '20220301.ig', '20220301.ii', '20220301.ik', '20220301.ilo', '20220301.inh', '20220301.io', '20220301.is', '20220301.it', '20220301.iu', '20220301.ja', '20220301.jam', '20220301.jbo', '20220301.jv', '20220301.ka', '20220301.kaa', '20220301.kab', '20220301.kbd', '20220301.kbp', '20220301.kg', '20220301.ki', '20220301.kj', '20220301.kk', '20220301.kl', '20220301.km', '20220301.kn', '20220301.ko', '20220301.koi', '20220301.krc', '20220301.ks', '20220301.ksh', '20220301.ku', '20220301.kv', '20220301.kw', '20220301.ky', '20220301.la', '20220301.lad', '20220301.lb', '20220301.lbe', '20220301.lez', '20220301.lfn', '20220301.lg', '20220301.li', '20220301.lij', '20220301.lmo', '20220301.ln', '20220301.lo', '20220301.lrc', '20220301.lt', '20220301.ltg', '20220301.lv', '20220301.mai', '20220301.map-bms', '20220301.mdf', '20220301.mg', '20220301.mh', '20220301.mhr', '20220301.mi', '20220301.min', '20220301.mk', '20220301.ml', '20220301.mn', '20220301.mr', '20220301.mrj', '20220301.ms', '20220301.mt', '20220301.mus', '20220301.mwl', '20220301.my', '20220301.myv', '20220301.mzn', '20220301.na', '20220301.nah', '20220301.nap', '20220301.nds', '20220301.nds-nl', '20220301.ne', '20220301.new', '20220301.ng', '20220301.nl', '20220301.nn', '20220301.no', '20220301.nov', '20220301.nrm', '20220301.nso', '20220301.nv', '20220301.ny', '20220301.oc', '20220301.olo', '20220301.om', '20220301.or', '20220301.os', '20220301.pa', '20220301.pag', '20220301.pam', '20220301.pap', '20220301.pcd', '20220301.pdc', '20220301.pfl', '20220301.pi', '20220301.pih', '20220301.pl', '20220301.pms', '20220301.pnb', '20220301.pnt', '20220301.ps', '20220301.pt', '20220301.qu', '20220301.rm', '20220301.rmy', '20220301.rn', '20220301.ro', '20220301.roa-rup', '20220301.roa-tara', '20220301.ru', '20220301.rue', '20220301.rw', '20220301.sa', '20220301.sah', '20220301.sat', '20220301.sc', '20220301.scn', '20220301.sco', '20220301.sd', '20220301.se', '20220301.sg', '20220301.sh', '20220301.si', '20220301.simple', '20220301.sk', '20220301.sl', '20220301.sm', '20220301.sn', '20220301.so', '20220301.sq', '20220301.sr', '20220301.srn', '20220301.ss', '20220301.st', '20220301.stq', '20220301.su', '20220301.sv', '20220301.sw', '20220301.szl', '20220301.ta', '20220301.tcy', '20220301.te', ' ...

# %%
from datasets import load_dataset

data = load_dataset('imdb', split="train")

# %%
data
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 25000
# })

# %%
from datasets import load_dataset_builder
dataset = load_dataset('imdb', split="train")

dataset.save_to_disk('imdb_dataset')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/25000 [00:00<?, ? examples/s]

# %% [markdown]
# # PIPELINES

# %% [markdown]
# # building pipelines with Hugging face
# - There are two ways that we can use to create pipelines
# - one uses transformers library and specifically, automodel class from the transformers library
# - Second way is using high level helper frameworks/library provided by huggingface

# %% [markdown]
# # Features of Automodel class
# - general class with multiple uses.
# - It is used to interact with models
# - It also has tokenizers
# - availability of configurations
# - processors
# - feature extractor
# - flexible and direct
# - more control for various tasks
# - We have individual subclasses for each task

# %% [markdown]
# # Pipeline wrapper library (2nd way of creating pipelines)
# - Pipeline class is also part of transformer library
# - contains all task specific steps
# - best for quickly performing tasks

# %% [markdown]
# **Automodel class implementation examples**

# %%
from transformers import AutoModelForSequenceClassification

model = AutoModelForSequenceClassification.from_pretrained("distilbert/distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
model
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): DistilBertSdpaAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# **The pipeline class/module**

# %%
from transformers import pipeline

my_pipeline = pipeline(task="text-classification")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
my_pipeline = pipeline(model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# Device set to use cuda:0

# %%
my_pipeline

# %%
my_pipeline = pipeline(task="text-classification", model = "distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
input_prompt = "I am very happy"

my_pipeline(input_prompt)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998795986175537}]

# %%
negative_prompt = "he rain poured relentlessly, mirroring the despair that weighed heavily on my heart. Everything seemed bleak and shrouded in a gloomy haze. A sense of unease settled deep within me, a knot of anxiety tightening with each passing moment. Disappointment gnawed at my soul, leaving behind a bitter taste of regret. The world felt cold and uncaring, as if it had conspired against my every hope and dream."

# %%
my_pipeline(negative_prompt)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9663328528404236}]

# %%
model(negative_prompt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-8603da09c844> in <cell line: 1>()
# ----> 1 model(negative_prompt)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     976         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     977
# --> 978         distilbert_output = self.distilbert(
#     979             input_ids=input_ids,
#     980             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     770             raise ValueError("You cannot specify both input_ids and inputs_embeds at the same time")
#     771         elif input_ids is not None:
# --> 772             self.warn_if_padding_and_no_attention_mask(input_ids, attention_mask)
#     773             input_shape = input_ids.size()
#     774         elif inputs_embeds is not None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in warn_if_padding_and_no_attention_mask(self, input_ids, attention_mask)
#    5029
#    5030         # Check only the first and last input IDs to reduce overhead.
# -> 5031         if self.config.pad_token_id in input_ids[:, [-1, 0]]:
#    5032             warn_string = (
#    5033                 "We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See "
#
# TypeError: string indices must be integers

# %%
from transformers import GPT2Tokenizer

input = "Hello ,,, !! how ARE you"

gpt_tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

gpt_tokens = gpt_tokenizer.tokenize(input)

print(gpt_tokens)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ['Hello', 'Ġ,', ',,', 'Ġ!!', 'Ġhow', 'ĠARE', 'Ġyou']

# %%
from transformers import GPT2Tokenizer, GPT2ForSequenceClassification

tokenizer = GPT2Tokenizer.from_pretrained("michelecafagna26/gpt2-medium-finetuned-sst2-sentiment")
model = GPT2ForSequenceClassification.from_pretrained("michelecafagna26/gpt2-medium-finetuned-sst2-sentiment")

inputs = tokenizer("I hate it", return_tensors="pt")

model(**inputs).logits.argmax(axis=1)

# 1: Positive, 0: Negative
# Output: tensor([1])
# Out:
# tensor([0])
