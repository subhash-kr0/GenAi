# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[0:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
#access rows and column of dataframe >>implicit/internal/integer indexing, explicit/named index

# %%
df.iloc[0:2] #start from o and go till 1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.loc[0:2] #loc is used for named indexes, iloc is used for integer indexes
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.iloc[0:2, ['Name', 'Parch']] #it will throw an error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.iloc[0:2, ['Name', 'Parch']] #it will throw an error
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[0:2, ['Name', 'Parch']]
# Out:
#                                                 Name  Parch
# 0                            Braund, Mr. Owen Harris      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0
# 2                             Heikkinen, Miss. Laina      0

# %%
df.iloc[0:2, 3:6]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
list(df['Name'][2:5])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
s = pd.Series(list(df['Name'][2:5]), index=['a', 'b', 'c'])

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1 = pd.Series(list(df['Name'][5:8]))

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
"pw"+"skills"
# Out:
# 'pwskills'

# %%
s+s1 #series and dataframe cannot be concatenated
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %%
#if you keep the index same, then for series concatenation can happen

s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1 = pd.Series(list(df['Name'][5:8]), index=['a', 'b', 'c'])
s1
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s+s1
# Out:
# a               Heikkinen, Miss. LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master. Gosta...
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId', axis=1, inplace=True)#axis =0>> rows, axis = 1 column, inplace =True means modify the original dataframe

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.reset_index(drop = True)
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                        Heikkinen, Miss. Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                      Allen, Mr. William Henry    male
# 4           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 885         0       2                         Montvila, Rev. Juozas    male
# 886         1       1                  Graham, Miss. Margaret Edith  female
# 887         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 888         1       1                         Behr, Mr. Karl Howell    male
# 889         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.set_index('Name', inplace=True)

# %%
df.loc['Braund, Mr. Owen Harris']
# Out:
# Survived            0
# Pclass              3
# Sex              male
# Age              22.0
# SibSp               1
# Parch               0
# Ticket      A/5 21171
# Fare             7.25
# Cabin             NaN
# Embarked            S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %%
d = {'key1': [2, 3, 4, 5],
    'key2': [4, 5, 6, 7],
    'key3': [2, 3, 4, 5]}

# %%
d
# Out:
# {'key1': [2, 3, 4, 5], 'key2': [4, 5, 6, 7], 'key3': [2, 3, 4, 5]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
d = {'key1': (2, 3, 4, 5),
    'key2': (4, 5, 6, 7),
    'key3': (2, 3, 4, 5)}

# %%
d
# Out:
# {'key1': (2, 3, 4, 5), 'key2': (4, 5, 6, 7), 'key3': (2, 3, 4, 5)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
df1 = pd.read_csv("taxonomy.csv")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.describe()
# Out:
#        taxonomy_id          name  parent_id       parent_name
# count          290           290        279               279
# unique         290           183         60                50
# top            101  Nursing Home  106-06-07  Health Education
# freq             1             4         11                15

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.isnull().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna() #remove null values row wise
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis = 1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1[['name']].dropna(axis=1) #for one column
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
#imputation of missing value
#numeric data>> mean and median>> outlier treatment done>>mean else media
#categorical>> mode
#impute missing values may be with some constant >>0

# %%
df1.fillna("somevalue")
# Out:
#     taxonomy_id                          name  parent_id           parent_name
# 0           101                     Emergency  somevalue             somevalue
# 1        101-01             Disaster Response        101             Emergency
# 2        101-02                Emergency Cash        101             Emergency
# 3     101-02-01             Help Pay for Food     101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare     101-02        Emergency Cash
# ..          ...                           ...        ...                   ...
# 285   111-01-07              Workplace Rights     111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation        111                 Legal
# 287      111-03                        Notary        111                 Legal
# 288      111-04                Representation        111                 Legal
# 289      111-05  Translation & Interpretation        111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna(0)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency         0                     0
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data1 = {
    'A': [1, 2, None, 4, 5, None, 7, 8, 9, 10],
    'B': [None, 11, 12, 13, None, 15, 16, None, 18, 19]
}

df2 = pd.DataFrame(data1)
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.A.fillna(df2['A'].mean())
# Out:
# 0     1.00
# 1     2.00
# 2     5.75
# 3     4.00
# 4     5.00
# 5     5.75
# 6     7.00
# 7     8.00
# 8     9.00
# 9    10.00
# Name: A, dtype: float64

# %%
df2.A.fillna(df2['A'].median())
# Out:
# 0     1.0
# 1     2.0
# 2     6.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(0)
# Out:
#       A     B
# 0   1.0   0.0
# 1   2.0  11.0
# 2   0.0  12.0
# 3   4.0  13.0
# 4   5.0   0.0
# 5   0.0  15.0
# 6   7.0  16.0
# 7   8.0   0.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna("something")
# Out:
#            A          B
# 0        1.0  something
# 1        2.0       11.0
# 2  something       12.0
# 3        4.0       13.0
# 4        5.0  something
# 5  something       15.0
# 6        7.0       16.0
# 7        8.0  something
# 8        9.0       18.0
# 9       10.0       19.0

# %%
df2.fillna(method = 'ffill') #forward fill>> start seeing from the bottom of dataframe and fill with the next value observed
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   2.0  12.0
# 3   4.0  13.0
# 4   5.0  13.0
# 5   5.0  15.0
# 6   7.0  16.0
# 7   8.0  16.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method = 'bfill') #backward fill>> see from top and fill with next observed value
# Out:
#       A     B
# 0   1.0  11.0
# 1   2.0  11.0
# 2   4.0  12.0
# 3   4.0  13.0
# 4   5.0  15.0
# 5   7.0  15.0
# 6   7.0  16.0
# 7   8.0  18.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df.mean()
# Out:
# /tmp/ipykernel_122/3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Survived     0.383146
# Pclass       2.310112
# Age         29.687475
# SibSp        0.522472
# Parch        0.382022
# Fare        32.160299
# dtype: float64

# %%
df.median()
# Out:
# /tmp/ipykernel_122/530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Survived     0.0000
# Pclass       3.0000
# Age         28.0000
# SibSp        0.0000
# Parch        0.0000
# Fare        14.4542
# dtype: float64

# %%
df.std()
# Out:
# /tmp/ipykernel_122/3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Survived     0.486427
# Pclass       0.835388
# Age         14.533361
# SibSp        1.103247
# Parch        0.806409
# Fare        49.704073
# dtype: float64

# %%
df.Age.describe()
# Out:
# count    713.000000
# mean      29.687475
# std       14.533361
# min        0.420000
# 25%       20.000000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %%
#Q. What is the average fare paid by people who survive?

# %%
#avg fare whosurvived
df[df.Survived == 1]['Fare'].mean()
# Out:
# 48.32828768328446

# %%
#avg fare who didnt survived
df[df.Survived == 0]['Fare'].mean()
# Out:
# 22.117886885245902

# %%
#groupby

df.groupby('Survived').mean(numeric_only = True)
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.310277  0.472141  0.466276  48.328288

# %%
df.groupby('Survived').min(numeric_only = True)
# Out:
#           Pclass   Age  SibSp  Parch  Fare
# Survived
# 0              1  1.00      0      0   0.0
# 1              1  0.42      0      0   0.0

# %%
df.groupby('Survived').sum(numeric_only = True)
# Out:
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8181.67    161    159  16479.9461

# %%
df.groupby('Survived').describe()
# Out:
#          Pclass                                                 Age  \
#           count      mean       std  min  25%  50%  75%  max  count
# Survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0  424.0
# 1         341.0  1.953079  0.863047  1.0  1.0  2.0  3.0  3.0  289.0
#
#                      ... Parch        Fare                             \
#                mean  ...   75%  max  count       mean        std  min
# Survived             ...
# 0         30.626179  ...   0.0  6.0  549.0  22.117887  31.388207  0.0
# 1         28.310277  ...   1.0  5.0  341.0  48.328288  66.683277  0.0
#
#
#               25%   50%   75%       max
# Survived
# 0          7.8542  10.5  26.0  263.0000
# 1         12.4750  26.0  57.0  512.3292
#
# [2 rows x 40 columns]

# %%
df[['Survived', 'Fare']]
# Out:
#      Survived     Fare
# 0           0   7.2500
# 1           1   7.9250
# 2           1  53.1000
# 3           0   8.0500
# 4           0   8.4583
# ..        ...      ...
# 885         0  13.0000
# 886         1  30.0000
# 887         0  23.4500
# 888         1  30.0000
# 889         0   7.7500
#
# [890 rows x 2 columns]

# %%
import numpy as np
df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean', 'median', 'count', np.std, 'var'])
# Out:
#           min       max       mean  median  count        std          var
# Survived
# 0         0.0  263.0000  22.117887    10.5    549  31.388207   985.219509
# 1         0.0  512.3292  48.328288    26.0    341  66.683277  4446.659477

# %% [markdown]
# #working of groupby
#
# ![image.png](attachment:bed09f9a-0154-48eb-9341-71c41d7445ea.png)

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum()
# Out:
# Sex     Pclass
# female  1         90
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1             90
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().unstack()
# Out:
# Pclass   1   2   3
# Sex
# female  90  70  72
# male    45  17  47

# %%
a = df.groupby('Pclass').sum(numeric_only = True)

# %%
a
# Out:
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7073.42     89     77  18106.1292
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
a.T
# Out:
# Pclass             1          2          3
# Survived    135.0000    87.0000   119.0000
# Age        7073.4200  5168.8300  8924.9200
# SibSp        89.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18106.1292  3801.8417  6714.6951

# %%
a.transpose()
# Out:
# Pclass             1          2          3
# Survived    135.0000    87.0000   119.0000
# Age        7073.4200  5168.8300  8924.9200
# SibSp        89.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18106.1292  3801.8417  6714.6951

# %%
df.head().T
# Out:
#                                            Name  Survived  Pclass     Sex  \
# 0                       Braund, Mr. Owen Harris         0       3    male
# 1                        Heikkinen, Miss. Laina         1       3  female
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                      Allen, Mr. William Henry         0       3    male
# 4                              Moran, Mr. James         0       3    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 2  35.0      1      0            113803  53.1000  C123        S
# 3  35.0      0      0            373450   8.0500   NaN        S
# 4   NaN      0      0            330877   8.4583   NaN        Q
