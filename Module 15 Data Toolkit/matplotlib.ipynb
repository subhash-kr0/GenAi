# %%
#why do we need visualisation? summarisation of data
#matplotlib, seaborn, plotly, bokeh
#matplotlib>> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#bar, hist, scatter plot, pie chart, line

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.04523672, 0.52678624, 0.57524324, 0.32017959, 0.48442014,
#        0.73400619, 0.71076542, 0.56423514, 0.34838059, 0.06658893,
#        0.64366268, 0.73815398, 0.9172139 , 0.76201737, 0.4002066 ,
#        0.74731113, 0.69100191, 0.4439244 , 0.02929531, 0.82891333,
#        0.98588218, 0.56973437, 0.58333432, 0.91776578, 0.91383099,
#        0.16790169, 0.48767348, 0.82980882, 0.59680928, 0.38792845,
#        0.39138941, 0.96058198, 0.59452399, 0.53653046, 0.24683249,
#        0.05101929, 0.23646572, 0.51956978, 0.55355343, 0.11729102,
#        0.54589883, 0.8860605 , 0.50266271, 0.0091404 , 0.35141896,
#        0.95306714, 0.33584584, 0.28434252, 0.87815803, 0.52260635])

# %%
y
# Out:
# array([0.73698061, 0.98277802, 0.03611394, 0.06617539, 0.07123898,
#        0.16568321, 0.04548929, 0.62589032, 0.14647129, 0.50208998,
#        0.09996937, 0.50900122, 0.08079532, 0.69794716, 0.32704163,
#        0.41690083, 0.10013573, 0.65649297, 0.10738925, 0.86043449,
#        0.75324767, 0.26143319, 0.72520091, 0.0894082 , 0.46520536,
#        0.26237297, 0.96765614, 0.742831  , 0.86534412, 0.6662345 ,
#        0.37864145, 0.22408526, 0.63930028, 0.07181247, 0.75889028,
#        0.20187134, 0.07532937, 0.45492099, 0.79583278, 0.06072711,
#        0.29307475, 0.31794915, 0.7241517 , 0.76023021, 0.77459806,
#        0.46739387, 0.56140306, 0.37085004, 0.2846484 , 0.73373756])

# %%
plt.scatter(x,y) #To understand the relationship between two variables

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['data'], index = pd.date_range('2024-03-29', periods =1000))

# %%
df
# Out:
#                 data
# 2024-03-29  0.139326
# 2024-03-30 -0.269635
# 2024-03-31 -0.744394
# 2024-04-01  0.232519
# 2024-04-02  0.112398
# ...              ...
# 2026-12-19 -1.029113
# 2026-12-20 -0.472041
# 2026-12-21 -0.631387
# 2026-12-22 -0.469771
# 2026-12-23 -0.072284
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8))
# Out:
# <Axes: >

# %%
#line plot
#whenever time component is involved on x axis
#depict the relation between two variables in the trend


x = [1, 2, 3, 4, 5]
y = [5, 1, 7, 8, 2]

plt.plot(x, y)

# %%
plt.plot(x, y)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red")
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o")
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--')
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 3)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=10)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=10)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]


plt.plot(x, y1, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=6, label = 'line y1')
plt.plot(x, y2, color = "b", marker = "o", linestyle = '--', linewidth = 3, markersize=10, label = 'line y2')

plt.xlabel("x data axis")
plt.ylabel("y data axis")

plt.title("Multiple lines in one plot")
plt.legend()

plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(1, 2, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 4)
plt.plot(x, np.cos(x+1))

plt.show()

# %%
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))


plt.show()

# %%
plt.plot(x, np.sin(x-0), color = "blue")

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)

plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#histogram>> continuous/numerical data distribution


data = np.random.randn(1000) #10 bins
plt.hist(data, color='r', bins = 20)
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
#stacked histogram


data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
data1
# Out:
# array([-1.11134156,  0.44954746, -0.71209574, ...,  0.07241827,
#        -1.1861498 ,  0.42298723])

# %%
data2
# Out:
# array([ 3.40887938,  3.65712612,  2.69851614, ...,  1.34283136,
#         1.42032828, -0.06936625])

# %%
plt.hist([data1, data2], bins = 20, color = ['r', 'b'], label = ['dist1', 'dist2'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.title("stacked histogram")
plt.show()

# %%
#scatter plot >> to understand the relationship between two features

x = np.random.rand(50)
y = np.random.rand(50)

x
# Out:
# array([0.62310656, 0.40336455, 0.59472641, 0.67586492, 0.65118469,
#        0.76680594, 0.66167269, 0.00530789, 0.47951912, 0.59598726,
#        0.39687239, 0.95480755, 0.01203725, 0.63245207, 0.66193227,
#        0.10920827, 0.31752998, 0.5062839 , 0.73998372, 0.33433287,
#        0.70462833, 0.22038494, 0.23513219, 0.55579573, 0.19175543,
#        0.27869464, 0.3052211 , 0.23334197, 0.13987511, 0.75334899,
#        0.26126477, 0.68513926, 0.68525783, 0.67531933, 0.05979578,
#        0.80630205, 0.21899882, 0.14420183, 0.02207371, 0.050267  ,
#        0.48758227, 0.16436772, 0.47849692, 0.41968418, 0.49510933,
#        0.16816315, 0.86030286, 0.27515067, 0.90955822, 0.52247516])

# %%
y
# Out:
# array([0.74406105, 0.0561467 , 0.21390797, 0.97387232, 0.8799093 ,
#        0.85680637, 0.68549095, 0.87431407, 0.61924468, 0.00402285,
#        0.94743189, 0.02377763, 0.97847841, 0.03755626, 0.89974618,
#        0.61732462, 0.82735471, 0.96168341, 0.74934423, 0.97216979,
#        0.36485344, 0.61288301, 0.05703085, 0.21445652, 0.83653546,
#        0.81889231, 0.12849367, 0.55462629, 0.80326345, 0.80070413,
#        0.78813392, 0.35492401, 0.30825885, 0.39247687, 0.92232772,
#        0.69104145, 0.17079068, 0.59489985, 0.12255304, 0.19317578,
#        0.42429495, 0.98890271, 0.24583387, 0.15093428, 0.87263938,
#        0.66185299, 0.51386825, 0.14275447, 0.14539784, 0.80034669])

# %%
plt.scatter(x, y, c = 'r', marker = 'X')

# %%
#bar plot >> To see the distribution of categorical variables

x = ['a', 'b', 'c', 'd']
y = [4, 6, 1, 2]


plt.bar(x, y, color = 'r')
# Out:
# <BarContainer object of 4 artists>

# %%
x = ['a', 'b', 'c', 'd']
y = [4, 6, 1, 2]


plt.barh(x, y, color = 'r')
# Out:
# <BarContainer object of 4 artists>

# %%
#pie chart >> To understand the percnt dist of data

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]


plt.pie(students, labels = langs, autopct = '%1.1f%%')
plt.title("Pie chart")
plt.show()

# %%
explode = (0.0, 0.1, 0.1)

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]


plt.pie(students, labels = langs, autopct = '%1.1f%%', explode = explode, shadow = True)
plt.title("Pie chart")
plt.show()

# %%
#3d plot

x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)


fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='red')

# %%
data = pd.read_csv("Bank_Churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.scatter(x = data['Age'], y=data['Balance'])

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'], color='red')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Balance'], color='red')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x18781f79150>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x18781f44150>,
#  'cmins': <matplotlib.collections.LineCollection at 0x18781f46110>,
#  'cbars': <matplotlib.collections.LineCollection at 0x18781ef3ad0>}

# %% [raw]
# #areaplot
# An area plot, also called a stacked area plot, is a type of data visualization that shows how various quantitative factors have changed over time while highlighting how they all work together to form the whole. It's particularly good for illustrating how elements of a whole change over time or along a continuous dimension.
# A layered representation of the data is produced in an area plot by layering many variables on top of one another. The cumulative influence of all levels provides insight into the overall trend. Each layer represents a separate category or variable. To distinguish between categories, the space beneath each layer is frequently colored.

# %%
import matplotlib.pyplot as plt

# Sample data
years = [2021, 2018, 2022, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

# Create a area plot
plt.stackplot(years, category1, category2, category3, labels=['Category 1', 'Category 2', 'Category 3'],
              colors=['skyblue', 'lightgreen', 'orange'])

# Add labels and title
plt.xlabel("Years")
plt.ylabel("Values")
plt.title("Area Plot")
plt.legend()

plt.show()
