# %%
#line chart >> time component on x axis and to know the trend
#scatter plot >> understand the relation between two numerical feature
#histogram>> to know the distribution of continuous data
#bar>> to know the distribution of categorical data
#boxplot and violin plot >> for outliers and distribution of data
#pie chart >> to know the proportions/percentage share
#area chart >>> to compare more than the two continuous variable
#pairplot >> plot pairwise relation between features of numerical data

# %%
#seaborn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings("ignore")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#line chart >> time component on x axis and to know the trend
#scatter plot >> understand the relation between two numerical feature
#histogram>> to know the distribution of continuous data
#bar>> to know the distribution of categorical data
#boxplot and violin plot >> for outliers and distribution of data
#pie chart >> to know the proportions/percentage share
#area chart >>> to compare more than the two continuous variable
#pairplot >> plot pairwise relation between features of numerical data

# %%
#numerical data plotting
sns.relplot(x = 'total_bill', y = 'tip', data = df)

# %%
#there is positive relation between tip and total bill
#highest tip is paid by highest bill person

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, kind = 'line')

# %%
sns.scatterplot(x = "total_bill", y = "tip", data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", data=df, hue = "smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#highest bill, tip was a smoker

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, hue = 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, hue = 'size')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, style = 'size')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, style = 'smoker', hue = 'time')

# %%
#relplot to make a line chart
time = np.arange(500)
value = np.random.randn(500).cumsum()
df = pd.DataFrame({"time": time, "value":value})

# %%
df
# Out:
#      time      value
# 0       0   1.387004
# 1       1   0.933406
# 2       2  -0.533659
# 3       3  -0.602576
# 4       4  -2.281086
# ..    ...        ...
# 495   495 -54.888981
# 496   496 -53.647773
# 497   497 -53.863304
# 498   498 -53.197455
# 499   499 -53.993673
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'time', y='value', kind = 'line', data=df, sort = True)

# %%
fmri = sns.load_dataset("fmri")

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri,)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri,hue = 'event')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri,hue = 'event', style = 'region')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri,hue = 'event', style = 'region', markers = True, dashes = False)

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', data=tips, col = "time")

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', data=tips, col = "size")

# %%
sns.catplot(x = 'day', y='total_bill', data=tips)

# %%
sns.catplot(x = 'day', y='total_bill', data=tips, kind = 'swarm')

# %%
sns.catplot(x = 'day', y='total_bill', data=tips, kind = 'box')

# %%
sns.catplot(x = 'day', y='total_bill', data=tips, kind = 'violin')

# %%
sns.catplot(x = 'day', y='total_bill', data=tips, kind = 'boxen')

# %%
sns.catplot(x = 'day', y='total_bill', data=tips, kind = 'bar')

# %%
sns.catplot(x = 'day', y='total_bill', data=tips, kind = 'point')

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip)

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'reg')

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'hex')

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'kde') #kernel density estimatior, contour >>meterological

# %%
#pairplot >> plot pairwise relation between features of numerical data

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue= 'smoker')

# %%
sns.pairplot(tips, hue= 'smoker', palette = 'pastel')

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, palette = "rainbow")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data = tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: >

# %%
tips = tips[['total_bill', 'tip', 'size']]

# %%
tips
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), annot=True, cmap = "coolwarm")
# Out:
# <Axes: >

# %%
tips = sns.load_dataset('tips')

# %%
sns.countplot(x = 'sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, height = 10, aspect =1)

# %%
#Plotly
import plotly.graph_objects as go
import plotly.express as px

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = [1, 2, 3, 4, 5], y = [1, 7, 8, 2, 3], mode = "markers"))
# Out:
# <div>                            <div id="ef57e1b5-3781-405f-b137-1b7fc3e2e771" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef57e1b5-3781-405f-b137-1b7fc3e2e771")) {                    Plotly.newPlot(                        "ef57e1b5-3781-405f-b137-1b7fc3e2e771",                        [{"mode":"markers","x":[1,2,3,4,5],"y":[1,7,8,2,3],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = [1, 2, 3, 4, 5], y = [1, 7, 8, 2, 3], mode = "lines"))
# Out:
# <div>                            <div id="9401b3c3-68e5-4584-86c5-a18057a8e110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9401b3c3-68e5-4584-86c5-a18057a8e110")) {                    Plotly.newPlot(                        "9401b3c3-68e5-4584-86c5-a18057a8e110",                        [{"mode":"lines","x":[1,2,3,4,5],"y":[1,7,8,2,3],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = tips.total_bill, y = tips.tip, mode = "markers"))
# Out:
# <div>                            <div id="2585b5ec-7a3e-43a8-bfa4-c0a86db354fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2585b5ec-7a3e-43a8-bfa4-c0a86db354fa")) {                    Plotly.newPlot(                        "2585b5ec-7a3e-43a8-bfa4-c0a86db354fa",                        [{"mode":"markers","x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.46,13.94,9.68,30.4,18.29,22.23,32.4,28.55,18.04,12.54,10.29,34.81,9.94,25.56,19.49,38.01,26.41,11.24,48.27,20.29,13.81,11.02,18.29,17.59,20.08,16.45,3.07,20.23,15.01,12.02,17.07,26.86,25.28,14.73,10
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = tips.total_bill, y = tips.tip, mode = "lines"))
# Out:
# <div>                            <div id="52aa993a-9989-4101-8ae1-30b20d775d92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52aa993a-9989-4101-8ae1-30b20d775d92")) {                    Plotly.newPlot(                        "52aa993a-9989-4101-8ae1-30b20d775d92",                        [{"mode":"lines","x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.46,13.94,9.68,30.4,18.29,22.23,32.4,28.55,18.04,12.54,10.29,34.81,9.94,25.56,19.49,38.01,26.41,11.24,48.27,20.29,13.81,11.02,18.29,17.59,20.08,16.45,3.07,20.23,15.01,12.02,17.07,26.86,25.28,14.73,10.5
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x = [1, 2, 3, 4, 5], y = [3, 8, 5, 2, 6]))
# Out:
# <div>                            <div id="a6bdd18d-a93b-49d0-ab75-6108fe3be84f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6bdd18d-a93b-49d0-ab75-6108fe3be84f")) {                    Plotly.newPlot(                        "a6bdd18d-a93b-49d0-ab75-6108fe3be84f",                        [{"x":[1,2,3,4,5],"y":[3,8,5,2,6],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x = tips['total_bill']))
# Out:
# <div>                            <div id="06d6ec6d-69dc-4789-a050-7739054f2289" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06d6ec6d-69dc-4789-a050-7739054f2289")) {                    Plotly.newPlot(                        "06d6ec6d-69dc-4789-a050-7739054f2289",                        [{"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.46,13.94,9.68,30.4,18.29,22.23,32.4,28.55,18.04,12.54,10.29,34.81,9.94,25.56,19.49,38.01,26.41,11.24,48.27,20.29,13.81,11.02,18.29,17.59,20.08,16.45,3.07,20.23,15.01,12.02,17.07,26.86,25.28,14.73,10.51,17.92,27.2,22
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = tips.total_bill, y = tips.tip, mode = "markers", marker_size = 12*tips['size']))
# Out:
# <div>                            <div id="171ebbfe-99ed-4d82-b0e1-1ac6648bb6f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("171ebbfe-99ed-4d82-b0e1-1ac6648bb6f2")) {                    Plotly.newPlot(                        "171ebbfe-99ed-4d82-b0e1-1ac6648bb6f2",                        [{"marker":{"size":[24,36,36,24,48,48,24,48,24,24,24,48,24,48,24,24,36,36,36,36,24,24,24,48,24,48,24,24,24,24,24,48,24,48,24,36,36,36,36,36,36,24,24,24,48,24,24,48,36,24,24,24,48,24,48,24,48,24,24,48,24,24,24,48,36,36,24,12,24,24,24,36,24,24,24,24,24,48,24,24,24,24,12,24,24,48,24,24,24,24,24,24,24,24,24,48,24,24,24,24,24,24,36,24,24,24,24,24,24,24,24,12,36,24,36,24,48,24,24,48,24,24,24,24,24,72,24,24,24,36,24,24,24,24,24,24,24,24,24,24,24,72,60,72,24,24,36,24,24,2
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x = tips.total_bill, y = tips.tip, mode = "markers", marker_size = 10*tips['size'], z = tips['size']))
# Out:
# <div>                            <div id="bc5a1b12-fa65-4000-8009-527a1f3a6d78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc5a1b12-fa65-4000-8009-527a1f3a6d78")) {                    Plotly.newPlot(                        "bc5a1b12-fa65-4000-8009-527a1f3a6d78",                        [{"marker":{"size":[20,30,30,20,40,40,20,40,20,20,20,40,20,40,20,20,30,30,30,30,20,20,20,40,20,40,20,20,20,20,20,40,20,40,20,30,30,30,30,30,30,20,20,20,40,20,20,40,30,20,20,20,40,20,40,20,40,20,20,40,20,20,20,40,30,30,20,10,20,20,20,30,20,20,20,20,20,40,20,20,20,20,10,20,20,40,20,20,20,20,20,20,20,20,20,40,20,20,20,20,20,20,30,20,20,20,20,20,20,20,20,10,30,20,30,20,40,20,20,40,20,20,20,20,20,60,20,20,20,30,20,20,20,20,20,20,20,20,20,20,20,60,50,60,20,20,30,20,20,2
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x = [1, 2, 3, 4, 5], y = [3, 8, 5, 2, 6], mode = 'lines', z = [1, 2, 7, 3, 5]))
# Out:
# <div>                            <div id="496e298c-5960-40bd-8eee-bd9aa398aa59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("496e298c-5960-40bd-8eee-bd9aa398aa59")) {                    Plotly.newPlot(                        "496e298c-5960-40bd-8eee-bd9aa398aa59",                        [{"mode":"lines","x":[1,2,3,4,5],"y":[3,8,5,2,6],"z":[1,2,7,3,5],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"
# ...

# %%
#using plotly express
x = [1, 2, 3, 4]
y = [10, 13, 15, 18]
fig = px.scatter(x, y)
fig.show()
# Out:
# <div>                            <div id="0ab9b71f-e507-4f70-bfac-05916bd7cfb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ab9b71f-e507-4f70-bfac-05916bd7cfb5")) {                    Plotly.newPlot(                        "0ab9b71f-e507-4f70-bfac-05916bd7cfb5",                        [{"hovertemplate":"x=%{x}<br>index=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":[10,13,15,18],"xaxis":"x","y":[0,1,2,3],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222
# ...

# %%
fig = px.line(x, y)
fig.show()
# Out:
# <div>                            <div id="2a035460-1087-4859-85c5-6038db5bca18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a035460-1087-4859-85c5-6038db5bca18")) {                    Plotly.newPlot(                        "2a035460-1087-4859-85c5-6038db5bca18",                        [{"hovertemplate":"x=%{x}<br>index=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[10,13,15,18],"xaxis":"x","y":[0,1,2,3],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,
# ...

# %%
x = ['A', 'B', 'C']
y = [5, 10, 3]
fig = px.bar(x =x, y=y)
fig.show()
# Out:
# <div>                            <div id="905b14f9-4c93-4bdc-bdd0-25faf6fbd2cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("905b14f9-4c93-4bdc-bdd0-25faf6fbd2cb")) {                    Plotly.newPlot(                        "905b14f9-4c93-4bdc-bdd0-25faf6fbd2cb",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["A","B","C"],"xaxis":"x","y":[5,10,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],
# ...

# %%
px.histogram([1,1,1,2,2,2,3,3,5, 5, 3, 1, 4, 5, 2, 67, 89, 34, 56, 74, 57,23])
# Out:
# <div>                            <div id="4aae6157-941e-45db-a35a-4c4167e2d7ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4aae6157-941e-45db-a35a-4c4167e2d7ad")) {                    Plotly.newPlot(                        "4aae6157-941e-45db-a35a-4c4167e2d7ad",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[1,1,1,2,2,2,3,3,5,5,3,1,4,5,2,67,89,34,56,74,57,23],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewi
# ...

# %%
x = ['A', 'B', 'C']
y = [5, 10, 3, 25, 12, 33, 100]
fig = px.box(x, y)
fig.show()
# Out:
# <div>                            <div id="d0a97657-9def-4783-9426-f76c1558dfa5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0a97657-9def-4783-9426-f76c1558dfa5")) {                    Plotly.newPlot(                        "d0a97657-9def-4783-9426-f76c1558dfa5",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[5,10,3,25,12,33,100],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4603
# ...

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
px.imshow(data)
# Out:
# <div>                            <div id="7bc22336-660b-4b17-afdd-056420c26892" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bc22336-660b-4b17-afdd-056420c26892")) {                    Plotly.newPlot(                        "7bc22336-660b-4b17-afdd-056420c26892",                        [{"coloraxis":"coloraxis","name":"0","z":[[1,2,3],[4,5,6],[7,8,9]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],
# ...

# %%
x = [1, 2, 3, 4]
y = [10, 13, 15, 18]
px.scatter(x, y, size = [30, 10, 50, 200])
# Out:
# <div>                            <div id="e379ceb7-4f60-43aa-8f3b-c5cfcdd3ef37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e379ceb7-4f60-43aa-8f3b-c5cfcdd3ef37")) {                    Plotly.newPlot(                        "e379ceb7-4f60-43aa-8f3b-c5cfcdd3ef37",                        [{"hovertemplate":"x=%{x}<br>index=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[30,10,50,200],"sizemode":"area","sizeref":0.5,"symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":[10,13,15,18],"xaxis":"x","y":[0,1,2,3],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks"
# ...

# %%
#3d chart
x = [1, 2, 3, 4]
y = [5, 8, 12, 3]
z = [3, 4, 5, 6]
px.scatter_3d(x = x, y=y, z=z)
# Out:
# <div>                            <div id="ada13f44-2966-4b72-8d55-be0d8c00d16e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ada13f44-2966-4b72-8d55-be0d8c00d16e")) {                    Plotly.newPlot(                        "ada13f44-2966-4b72-8d55-be0d8c00d16e",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[1,2,3,4],"y":[5,8,12,3],"z":[3,4,5,6],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222222
# ...

# %%
#contour plot
x = [1, 2, 3, 4, 3, 23, 80]
y = [5, 8, 12, 3, 12, 35, 60]
px.density_contour(x, y)
# Out:
# <div>                            <div id="ec7fb6ab-fd31-4dd2-b08a-95565d9a25ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec7fb6ab-fd31-4dd2-b08a-95565d9a25ef")) {                    Plotly.newPlot(                        "ec7fb6ab-fd31-4dd2-b08a-95565d9a25ef",                        [{"contours":{"coloring":"none"},"hovertemplate":"x=%{x}<br>index=%{y}<br>count=%{z}<extra></extra>","legendgroup":"","line":{"color":"#636efa"},"name":"","showlegend":false,"x":[5,8,12,3,12,35,60],"xaxis":"x","xbingroup":"x","y":[0,1,2,3,4,5,6],"yaxis":"y","ybingroup":"y","type":"histogram2dcontour"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887
# ...

# %%
x = [1, 2, 3, 4, 3, 23, 80]
y = [5, 8, 12, 3, 12, 35, 60]
px.density_heatmap(x, y)
# Out:
# <div>                            <div id="99a9f642-45df-47ea-8e01-c9ba902e8c45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99a9f642-45df-47ea-8e01-c9ba902e8c45")) {                    Plotly.newPlot(                        "99a9f642-45df-47ea-8e01-c9ba902e8c45",                        [{"coloraxis":"coloraxis","hovertemplate":"x=%{x}<br>index=%{y}<br>count=%{z}<extra></extra>","name":"","x":[5,8,12,3,12,35,60],"xaxis":"x","xbingroup":"x","y":[0,1,2,3,4,5,6],"yaxis":"y","ybingroup":"y","type":"histogram2d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333
# ...

# %%
#bokeh

import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ae73d3d6-5289-4858-89cf-28d9f9a8133f">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure, output_file, show

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')
p = figure()
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="f666e3d8-0c98-4ee8-b60c-d8ae30dc91bf" data-root-id="p1040" style="display: contents;"></div>

# %%
output_file('test1.html')
p = figure()
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="f35707e1-3507-46b2-b9f7-5793c00cbd17" data-root-id="p1082" style="display: contents;"></div>

# %%
output_file('test1.html')
p = figure()
p.line(x = [1, 2, 3, 4], y = [3, 8, 4, 7])
show(p)
# Out:
#   <div id="b6af80b3-2e0c-4873-86f7-13ca30f4006b" data-root-id="p1124" style="display: contents;"></div>
