# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data = [1,2, 3, 4, 5]
np.mean(data)
# Out:
# 3.0

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
np.mean(df['total_bill']) #The average bill paid by the customer is 19
# Out:
# 19.78594262295082

# %%
np.median(data)
# Out:
# 3.0

# %%
np.median(df['total_bill'])
# Out:
# 17.795

# %%
#mean is inflated by outlier
data = [1, 2, 3, 4, 500]

# %%
np.median(data)
# Out:
# 3.0

# %%
np.mean(data)
# Out:
# 102.0

# %%
data = [1, 2,3, 3, 3, 3, 4, 500]

# %%
np.mode(data) #throw error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 np.mode(data)
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
import statistics
statistics.mode(data)
# Out:
# 3

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
np.percentile(data, [25, 50, 75, 100])
# Out:
# array([  2.75,   3.  ,   3.25, 500.  ])

# %%
data = [-100, 10, 20, 30, 30, 30, 30, 80, 70, 80, 60, 70, 40, 100]

# %%
#boxplot
sns.boxplot(data)
# Out:
# <Axes: >

# %%
np.var(data)
# Out:
# 2163.7755102040815

# %%
np.std(data)
# Out:
# 46.516400443328386

# %%
statistics.variance(data) #sample var
# Out:
# 2330.21978021978

# %%
statistics.pvariance(data)
# Out:
# 2163.7755102040815

# %%
import math
math.sqrt(statistics.pvariance(data))
# Out:
# 46.516400443328386

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.cov(numeric_only = True)
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
sns.pairplot(df)

# %%
sns.distplot(df['total_bill'], kde = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
np.random.normal(0.5, 0.2, 100)
# Out:
# array([ 0.30466344,  0.86001707,  0.42548498,  0.71353337,  0.45135614,
#         0.23052692,  0.4328193 ,  0.87910392,  0.63094661,  0.27471216,
#         0.80174214,  0.57712461,  0.54699015,  0.56870409,  0.60909105,
#         0.45462003,  0.41837783,  0.48925437,  0.62607494,  0.37626936,
#         0.37796508,  0.59899113,  0.3142085 ,  0.48345995,  0.44252868,
#         0.61604945,  0.86963201,  0.41365415,  0.57883288,  0.3937111 ,
#         0.4730776 ,  0.52026204,  0.59781599,  0.66528349,  0.7744064 ,
#         0.41824266,  0.66783688,  1.05888798,  0.67601744,  0.70064699,
#         0.54074913, -0.03878768,  0.39405541,  0.80275777,  0.57858906,
#         0.37096779,  0.4224763 ,  0.92084987,  0.34317332,  0.49846401,
#         0.49495913,  0.47059711,  0.54482942,  0.92327501,  0.5111305 ,
#         0.65167174,  0.35101895,  0.76933895,  0.2353525 ,  0.43203044,
#         0.35808919,  0.50847775,  0.56533374,  0.51897841,  0.89654445,
# ...

# %%
sns.distplot(np.random.normal(0.5, 0.2, 10000))
# Out:
# <Axes: ylabel='Density'>

# %%
population = np.random.randint(10, 20, 50)
population
# Out:
# array([12, 13, 11, 17, 13, 11, 17, 17, 12, 11, 15, 17, 19, 10, 14, 16, 11,
#        18, 11, 10, 17, 14, 19, 10, 11, 11, 11, 13, 15, 16, 16, 13, 13, 14,
#        11, 10, 16, 13, 18, 12, 17, 17, 16, 17, 11, 17, 12, 16, 19, 15])

# %%
sample1 = np.random.choice(population, 30)
sample2 = np.random.choice(population, 30)
sample3 = np.random.choice(population, 30)
sample4 = np.random.choice(population, 30)

# %%
np.mean(sample2)
# Out:
# 14.733333333333333

# %%
mean_of_samples = []
all_sample = [sample1, sample2, sample3, sample4]
for sample in all_sample:
    mean_of_samples.append(np.mean(sample))
mean_of_samples
# Out:
# [14.533333333333333,
#  14.733333333333333,
#  14.966666666666667,
#  14.066666666666666]

# %%
#clt>> the smaple mean distribution willm be approximated to normal dist


population = np.random.binomial(10, 0.5, 100000)
population
# Out:
# array([3, 8, 6, ..., 4, 4, 7])

# %%
sns.distplot(population)
# Out:
# <Axes: ylabel='Density'>

# %%
sample_size = 3000
mean_of_samples = []
for i in range(1, 1000):
    sample = np.random.choice(population, size = sample_size)
    mean_of_samples.append(np.mean(sample))
len(mean_of_samples)
# Out:
# 999

# %%
sns.distplot(mean_of_samples, kde = True, color = "red")
# Out:
# <Axes: ylabel='Density'>

# %%
#ztestf
population = np.random.randn(100)

# %%
sns.distplot(population)
# Out:
# <Axes: ylabel='Density'>

# %%
np.mean(population), np.std(population)
# Out:
# (0.0038730246748578125, 1.0648532910042816)
